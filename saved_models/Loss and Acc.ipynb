# %%
cd treelstm/saved_models
# Out:
# /Users/uabhifn/treelstm/saved_models

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
directory = os.path.join(".","")

# %%
for root,dirs,files in os.walk(directory):
    for file in files:
        if file.endswith(".csv"):
            print(file)
            df = pd.read_csv(file)
            loss_train = df['Train Loss']
            loss_val = df['Val Loss']
            acc_train = df['Train Acc']
            acc_val = df['Val Acc']
            epochs = range(len(df))
            plt.plot(epochs, loss_train, 'g', label='Training loss')
            plt.plot(epochs, loss_val, 'b', label='validation loss')
            plt.title('Training and Validation loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.legend()
            plt.show()
            
            plt.plot(epochs, acc_train, 'g', label='Training acc')
            plt.plot(epochs, acc_val, 'b', label='validation acc')
            plt.title('Training and Validation acc')
            plt.xlabel('Epochs')
            plt.ylabel('Acc')
            plt.legend()
            plt.show()
# Out:
# bert_10_normal_0.9_32_1e-07_9.999999999999999e-11_losses_and_acc.csv
# bert+treelstm_3_normal_0.2_64_1e-06_1e-08_losses_and_acc.csv
# bert+treelstm_7_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# treelstm_10_normal_0.9_32_1e-07_9.999999999999999e-11_losses_and_acc.csv
# bert+treelstm_3_xavier_0.5_16_1e-06_1e-08_losses_and_acc.csv
# bert_3_xavier_0.5_64_1e-06_1e-07_losses_and_acc.csv
# bert+treelstm_3_xavier_0.2_32_0.0001_1e-05_losses_and_acc.csv
# bert_10_xavier_0.5_32_0.001_1e-06_losses_and_acc.csv
# treelstm_10_xavier_0.5_32_0.001_1e-06_losses_and_acc.csv
# bert_7_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# treelstm_7_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# treelstm_3_xavier_0.5_16_1e-06_1e-08_losses_and_acc.csv
# bert_7_xavier_0.5_64_0.001_1e-06_losses_and_acc.csv
# bert+treelstm_10_normal_0.9_32_1e-07_9.999999999999999e-11_losses_and_acc.csv
# treelstm_3_xavier_0.2_32_0.0001_1e-05_losses_and_acc.csv
# bert_3_xavier_0.2_32_0.0001_1e-05_losses_and_acc.csv
# bert+treelstm_10_xavier_0.5_32_0.001_1e-06_losses_and_acc.csv
# treelstm_3_normal_0.2_64_1e-06_1e-08_losses_and_acc.csv
# bert+treelstm_7_xavier_0.5_64_0.001_1e-06_losses_and_acc.csv
# bert+treelstm_10_xavier_0.5_32_1e-07_9.999999999999999e-11_losses_and_acc.csv
# bert+treelstm_3_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# treelstm_3_xavier_0.5_64_1e-06_1e-07_losses_and_acc.csv
# bert_3_xavier_0.5_16_1e-06_1e-08_losses_and_acc.csv
# bert+treelstm_3_xavier_0.5_64_1e-06_1e-07_losses_and_acc.csv
# bert_3_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# treelstm_3_normal_0.5_16_0.0001_1e-05_losses_and_acc.csv
# bert_3_normal_0.2_64_1e-06_1e-08_losses_and_acc.csv
# treelstm_10_xavier_0.5_32_1e-07_9.999999999999999e-11_losses_and_acc.csv
# treelstm_7_xavier_0.5_64_0.001_1e-06_losses_and_acc.csv
